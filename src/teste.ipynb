# %%
import geopandas as gpd

df = gpd.read_file('../data/gpw_grassland_fscs.vi.vhr.harm_point.samples_20000101_20241231_go_epsg.4326_v2.gpkg')

# %%
df
# Out:
#                                 sample_id           x          y vi_tile_id  \
# 0        ac2481b4a32acd202599791c3a3ab025 -127.001945  64.669586       1748
# 1        886d6c1712dff678cec1828ed50a9b7c -127.001450  64.669586       1748
# 2        75ea28cdc5b0f3479c041eb5d71ca9c3 -127.000946  64.669586       1748
# 3        a681e28109b6cafd2cd8da452b26919b -127.000450  64.669586       1748
# 4        e1ba66af8657c687a4749ae5074c9dc9 -126.999451  64.669586       1748
# ...                                   ...         ...        ...        ...
# 3129070                              None  -71.846497   4.894500        nan
# 3129071                              None  -71.846252   4.894500        nan
# 3129072                              None  -71.846001   4.894500        nan
# 3129073                              None  -71.845749   4.894500        nan
# 3129074                              None  -71.845749   4.894250        nan
#
#           tile_id imagery   ref_date  year  class  \
# ...
