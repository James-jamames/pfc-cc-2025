# %%
import pandas as pd

df = pd.read_parquet("../data/samples.pq", columns=['tile_id'])

# %%
df
# Out:
#          tile_id
# 0          1-mvp
# 1          1-mvp
# 2          1-mvp
# 3          1-mvp
# 4          1-mvp
# ...          ...
# 53266576    2158
# 53266577    2158
# 53266578    2158
# 53266579    2158
# 53266580    2158
#
# [53266581 rows x 1 columns]

# %%
df_filtrado
# Out:
#               B01       B02       B03       B04       B05       B06       B07  \
# 0       -0.035433 -0.103406 -0.041584 -0.093564 -0.113741 -0.251965 -0.001538
# 1        0.012057 -0.084214  0.001538 -0.103406 -0.088827 -0.228897  0.035433
# 2       -0.013841 -0.071111 -0.006151 -0.124567 -0.088827 -0.267958  0.048228
# 3       -0.019931 -0.103406 -0.017778 -0.071111 -0.093564 -0.259900  0.032541
# 4       -0.017778 -0.124567 -0.059116 -0.124567 -0.119093 -0.199862  0.001538
# ...           ...       ...       ...       ...       ...       ...       ...
# 5326663 -0.003014 -0.172795  0.192910 -0.259900 -0.066990  0.084214 -0.259900
# 5326664  0.019931 -0.192910  0.172795 -0.244152 -0.022207  0.103406 -0.251965
# 5326665  0.003014 -0.179377  0.214133 -0.244152 -0.098424  0.066990 -0.244152
# 5326666  0.051734 -0.206936  0.206936 -0.259900 -0.019931  0.103406 -0.244152
# 5326667 -0.044844 -0.206936  0.214133 -0.186082 -0.179377  0.013841 -0.147697
#
# ...

# %%
a = {}

a.update()
